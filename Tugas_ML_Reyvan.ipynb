# %% [markdown]
# <a href="https://colab.research.google.com/github/revvvv1/Diabates-Decision-Tree-Reyvan/blob/main/Tugas_ML_Reyvan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier # or DecisionTreeRegressor
from sklearn import metrics
import warnings
from sklearn import tree

# %%
Data = pd.read_csv("/content/diabetes.csv")
Data
# Out:
#      Pregnancies  Glucose  BloodPressure  Skinthickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
Data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  Skinthickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df_check = Data.isnull().sum()
print (df_check)
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# Skinthickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
X = pd.DataFrame(Data, columns=['Glucose','BloodPressure','Skinthickness','Insulin','BMI','DiabetesPedigreeFunction','Age'])
y = Data.Outcome.values.reshape(-1,1)
X
# Out:
#      Glucose  BloodPressure  Skinthickness  Insulin   BMI  \
# 0        148             72             35        0  33.6
# 1         85             66             29        0  26.6
# 2        183             64              0        0  23.3
# 3         89             66             23       94  28.1
# 4        137             40             35      168  43.1
# ..       ...            ...            ...      ...   ...
# 763      101             76             48      180  32.9
# 764      122             70             27        0  36.8
# 765      121             72             23      112  26.2
# 766      126             60              0        0  30.1
# 767       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# 763                     0.171   63
# 764                     0.340   27
# 765                     0.245   30
# 766                     0.349   47
# 767                     0.315   23
#
# [768 rows x 7 columns]

# %%
X_train, X_test, y_train , y_test = train_test_split(X,y, test_size=0.3, random_state=1)

# %%
clf = DecisionTreeClassifier(max_depth=3) # Quality of the splite based on "gini" for the gini impurity
clf= clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)

# %%
print('Accuracy:', metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy: 0.7575757575757576

# %%
text_representation = tree.export_text (clf)
print (text_representation)
# Out:
# |--- feature_0 <= 129.50
# |   |--- feature_4 <= 26.30
# |   |   |--- feature_4 <= 9.10
# |   |   |   |--- class: 0
# |   |   |--- feature_4 >  9.10
# |   |   |   |--- class: 0
# |   |--- feature_4 >  26.30
# |   |   |--- feature_6 <= 27.50
# |   |   |   |--- class: 0
# |   |   |--- feature_6 >  27.50
# |   |   |   |--- class: 0
# |--- feature_0 >  129.50
# |   |--- feature_4 <= 27.85
# |   |   |--- feature_0 <= 145.50
# |   |   |   |--- class: 0
# |   |   |--- feature_0 >  145.50
# |   |   |   |--- class: 0
# |   |--- feature_4 >  27.85
# |   |   |--- feature_0 <= 158.50
# |   |   |   |--- class: 1
# |   |   |--- feature_0 >  158.50
# |   |   |   |--- class: 1

# %%
with open ("description_tree.log", "w") as fout:
    fout.write(text_representation)

# %%
feature_names = ['Glucose','BloodPressure','Skinthickness','Insulin','BMI','DiabetesPedigreeFunction','Age']
target_names = ['0', '1']
fig= plt.figure(figsize=(23,20))
Plot = tree.plot_tree(clf,
                      feature_names= feature_names,
                      class_names = target_names,
                      filled = True)
fig.savefig('Tree1.png')

# %%
clf = DecisionTreeClassifier(criterion ='entropy',max_depth=3) ## Quality of the splite based on "entropy" for the information gain
clf= clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)

# %%
print('Accuracy:', metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy: 0.7705627705627706

# %%
feature_names = ['Glucose','BloodPressure','Skinthickness','Insulin','BMI','DiabetesPedigreeFunction','Age']
target_names = ['0', '1']
fig= plt.figure(figsize=(23,20))
Plot = tree.plot_tree(clf,
                      feature_names= feature_names,
                      class_names = target_names,
                      filled = True)
fig.savefig('Tree2.png')
